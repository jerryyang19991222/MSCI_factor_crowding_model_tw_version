# %%
import pandas as pd
import numpy as np
import importlib
import analysis_tool_crowding_model as tool
importlib.reload(tool)
# Out:
# <module 'analysis_tool_crowding_model' from '/Users/yangzherui/Desktop/py coding/因子研究/MSCI因子擁擠模型/analysis_tool_crowding_model.py'>

# %%
pairwise_corr=pd.read_pickle('/Users/yangzherui/Desktop/py coding/因子研究/MSCI因子擁擠模型/handler/crowdind_score.pkl')
factor_index=pd.read_pickle('/Users/yangzherui/Desktop/py coding/因子研究/MSCI因子擁擠模型/handler/factor_index_quantile_ls.pkl')

# %%
tool.corr_analysis(factor_index,pairwise_corr,[5,20,60,120,240,480])

# %%
tool.mdd_analysis(pairwise_corr,factor_index)

# %%
tool.future_month_return(pairwise_corr,factor_index)

# %%
tool.future_month_volitity(pairwise_corr,factor_index)

# %%
tool.future_month_sharpe(pairwise_corr,factor_index)

# %%
tool.analysis_crowding_factor(pairwise_corr,date='2025-04-28')
